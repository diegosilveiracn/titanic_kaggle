# %% [markdown]
# # Titanic
#
# This notebook presents a simple solution for Titanic problem.
#
# #### Table of contents
# <ol>
#     <li>Libraries</li>
#     <li>Import Data</li>
#     <li>Clean and Transformation Data</li>
#     <li>Data Analisis</li>
#     <li>Prediction</li>
# </ol>

# %% [markdown]
# ## 1 - Libraries

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.neural_network import MLPClassifier

# %% [markdown]
# ## 2 - Import Data

# %%
df_train = pd.read_csv('train.csv')

# %%
df_train.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df_test = pd.read_csv('test.csv')

# %%
df_test.head(3)
# Out:
#    PassengerId  Pclass                              Name     Sex   Age  SibSp  \
# 0          892       3                  Kelly, Mr. James    male  34.5      0
# 1          893       3  Wilkes, Mrs. James (Ellen Needs)  female  47.0      1
# 2          894       2         Myles, Mr. Thomas Francis    male  62.0      0
#
#    Parch  Ticket    Fare Cabin Embarked
# 0      0  330911  7.8292   NaN        Q
# 1      0  363272  7.0000   NaN        S
# 2      0  240276  9.6875   NaN        Q

# %% [markdown]
# ## 3 - Clean and Transformation Date

# %%
df = df_train.append(df_test,ignore_index=True,sort=False)

# %%
df.tail(5)
# Out:
#       PassengerId  Survived  Pclass                          Name     Sex  \
# 1304         1305       NaN       3            Spector, Mr. Woolf    male
# 1305         1306       NaN       1  Oliva y Ocana, Dona. Fermina  female
# 1306         1307       NaN       3  Saether, Mr. Simon Sivertsen    male
# 1307         1308       NaN       3           Ware, Mr. Frederick    male
# 1308         1309       NaN       3      Peter, Master. Michael J    male
#
#        Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# 1304   NaN      0      0           A.5. 3236    8.0500   NaN        S
# 1305  39.0      0      0            PC 17758  108.9000  C105        C
# 1306  38.5      0      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 1307   NaN      0      0              359309    8.0500   NaN        S
# 1308   NaN      1      1                2668   22.3583   NaN        C

# %% [markdown]
# ### PassengerId e Ticket

# %%
df.drop(['PassengerId','Ticket'],axis=1,inplace=True)

# %%
df.head(3)
# Out:
#    Survived  Pclass                                               Name  \
# 0       0.0       3                            Braund, Mr. Owen Harris
# 1       1.0       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2       1.0       3                             Heikkinen, Miss. Laina
#
#       Sex   Age  SibSp  Parch     Fare Cabin Embarked
# 0    male  22.0      1      0   7.2500   NaN        S
# 1  female  38.0      1      0  71.2833   C85        C
# 2  female  26.0      0      0   7.9250   NaN        S

# %%
df.isnull().sum()
# Out:
# Survived     418
# Pclass         0
# Name           0
# Sex            0
# Age          263
# SibSp          0
# Parch          0
# Fare           1
# Cabin       1014
# Embarked       2
# dtype: int64

# %% [markdown]
# ### Sex

# %%
list_sex = df['Sex'].unique()

# %%
list_sex
# Out:
# array(['male', 'female'], dtype=object)

# %%
map_sex = {list_sex[x]: x for x in range(len(list_sex))}

# %%
map_sex
# Out:
# {'male': 0, 'female': 1}

# %%
df['Sex'] = df['Sex'].map(map_sex)

# %%
df.head(3)
# Out:
#    Survived  Pclass                                               Name  Sex  \
# 0       0.0       3                            Braund, Mr. Owen Harris    0
# 1       1.0       1  Cumings, Mrs. John Bradley (Florence Briggs Th...    1
# 2       1.0       3                             Heikkinen, Miss. Laina    1
#
#     Age  SibSp  Parch     Fare Cabin Embarked
# 0  22.0      1      0   7.2500   NaN        S
# 1  38.0      1      0  71.2833   C85        C
# 2  26.0      0      0   7.9250   NaN        S

# %% [markdown]
# ### Cabin

# %%
df['Cabin'] = df.apply(lambda x: 0 if pd.isna(x['Cabin']) else 1,axis=1)

# %%
df.head(3)
# Out:
#    Survived  Pclass                                               Name  Sex  \
# 0       0.0       3                            Braund, Mr. Owen Harris    0
# 1       1.0       1  Cumings, Mrs. John Bradley (Florence Briggs Th...    1
# 2       1.0       3                             Heikkinen, Miss. Laina    1
#
#     Age  SibSp  Parch     Fare  Cabin Embarked
# 0  22.0      1      0   7.2500      0        S
# 1  38.0      1      0  71.2833      1        C
# 2  26.0      0      0   7.9250      0        S

# %% [markdown]
# ### Embarked

# %%
df['Embarked'] = df['Embarked'].fillna('S')

# %%
embarked = pd.get_dummies(df['Embarked'],prefix='Embarked')

# %%
df = pd.concat([df,embarked],axis=1,sort=False)

# %%
df.head(3)
# Out:
#    Survived  Pclass                                               Name  Sex  \
# 0       0.0       3                            Braund, Mr. Owen Harris    0
# 1       1.0       1  Cumings, Mrs. John Bradley (Florence Briggs Th...    1
# 2       1.0       3                             Heikkinen, Miss. Laina    1
#
#     Age  SibSp  Parch     Fare  Cabin Embarked  Embarked_C  Embarked_Q  \
# 0  22.0      1      0   7.2500      0        S           0           0
# 1  38.0      1      0  71.2833      1        C           1           0
# 2  26.0      0      0   7.9250      0        S           0           0
#
#    Embarked_S
# 0           1
# 1           0
# 2           1

# %%
df.drop(['Embarked'],axis=1,inplace=True)

# %%
df.head(3)
# Out:
#    Survived  Pclass                                               Name  Sex  \
# 0       0.0       3                            Braund, Mr. Owen Harris    0
# 1       1.0       1  Cumings, Mrs. John Bradley (Florence Briggs Th...    1
# 2       1.0       3                             Heikkinen, Miss. Laina    1
#
#     Age  SibSp  Parch     Fare  Cabin  Embarked_C  Embarked_Q  Embarked_S
# 0  22.0      1      0   7.2500      0           0           0           1
# 1  38.0      1      0  71.2833      1           1           0           0
# 2  26.0      0      0   7.9250      0           0           0           1

# %% [markdown]
# ### Fare

# %%
df.loc[pd.isna(df['Fare'])]
# Out:
#       Survived  Pclass                Name  Sex   Age  SibSp  Parch  Fare  \
# 1043       NaN       3  Storey, Mr. Thomas    0  60.5      0      0   NaN
#
#       Cabin  Embarked_C  Embarked_Q  Embarked_S
# 1043      0           0           0           1

# %%
medias = df[['Pclass','Fare']].groupby('Pclass').mean()['Fare']
medias
# Out:
# Pclass
# 1    87.508992
# 2    21.179196
# 3    13.302889
# Name: Fare, dtype: float64

# %%
df['Fare'] = df['Fare'].fillna(medias[3])

# %%
df.loc[1043]
# Out:
# Survived                     NaN
# Pclass                         3
# Name          Storey, Mr. Thomas
# Sex                            0
# Age                         60.5
# SibSp                          0
# Parch                          0
# Fare                     13.3029
# Cabin                          0
# Embarked_C                     0
# Embarked_Q                     0
# Embarked_S                     1
# Name: 1043, dtype: object

# %% [markdown]
# ### Name

# %%
title = [i.split(",")[1].split(".")[0].strip() for i in df["Name"]]

# %%
df['Title'] = title

# %%
df.head(3)
# Out:
#    Survived  Pclass                                               Name  Sex  \
# 0       0.0       3                            Braund, Mr. Owen Harris    0
# 1       1.0       1  Cumings, Mrs. John Bradley (Florence Briggs Th...    1
# 2       1.0       3                             Heikkinen, Miss. Laina    1
#
#     Age  SibSp  Parch     Fare  Cabin  Embarked_C  Embarked_Q  Embarked_S  \
# 0  22.0      1      0   7.2500      0           0           0           1
# 1  38.0      1      0  71.2833      1           1           0           0
# 2  26.0      0      0   7.9250      0           0           0           1
#
#   Title
# 0    Mr
# 1   Mrs
# 2  Miss

# %%
df.drop(['Name'],axis=1,inplace=True)

# %%
df.head(3)
# Out:
#    Survived  Pclass  Sex   Age  SibSp  Parch     Fare  Cabin  Embarked_C  \
# 0       0.0       3    0  22.0      1      0   7.2500      0           0
# 1       1.0       1    1  38.0      1      0  71.2833      1           1
# 2       1.0       3    1  26.0      0      0   7.9250      0           0
#
#    Embarked_Q  Embarked_S Title
# 0           0           1    Mr
# 1           0           0   Mrs
# 2           0           1  Miss

# %%
df['Title'].value_counts()
# Out:
# Mr              757
# Miss            260
# Mrs             197
# Master           61
# Rev               8
# Dr                8
# Col               4
# Ms                2
# Major             2
# Mlle              2
# Jonkheer          1
# Sir               1
# the Countess      1
# Capt              1
# Don               1
# Lady              1
# Dona              1
# Mme               1
# Name: Title, dtype: int64

# %% [markdown]
# 0: Mr
#
# 1: Mrs/Miss/Mme/Ms
#
# 2: Master
#
# 3: Don/Rev/Dr/Major/Lady/Sir/Mlle/Col/Capt/the Countess/Jonkheer/Dona

# %%
df['Title'] = df['Title'].map({'Mr': 0, 'Mrs':1, 'Miss': 1, 'Mme': 1, 'Ms': 1, 'Master': 2, 'Don': 3, 'Rev': 3, 'Dr': 3, 'Major': 3, 'Lady': 3, 'Sir': 3, 'Mlle': 3, 'Col': 3, 'Capt': 3, 'the Countess': 3, 'Jonkheer': 3, 'Dona': 3})

# %%
df.head(3)
# Out:
#    Survived  Pclass  Sex   Age  SibSp  Parch     Fare  Cabin  Embarked_C  \
# 0       0.0       3    0  22.0      1      0   7.2500      0           0
# 1       1.0       1    1  38.0      1      0  71.2833      1           1
# 2       1.0       3    1  26.0      0      0   7.9250      0           0
#
#    Embarked_Q  Embarked_S  Title
# 0           0           1      0
# 1           0           0      1
# 2           0           1      1

# %%
df['Title'].value_counts()
# Out:
# 0    757
# 1    468
# 2     53
# 3     31
# Name: Title, dtype: int64

# %% [markdown]
# ### Age

# %%
media_idade_por_titulo = df[['Title','Age']].groupby('Title').mean()

# %%
media_idade_por_titulo
# Out:
#              Age
# Title
# 0      32.252151
# 1      28.569607
# 2       5.482642
# 3      43.766667

# %%
df.loc[pd.isna(df['Age'])]
# Out:
#       Survived  Pclass  Sex  Age  SibSp  Parch     Fare  Cabin  Embarked_C  \
# 5          0.0       3    0  NaN      0      0   8.4583      0           0
# 17         1.0       2    0  NaN      0      0  13.0000      0           0
# 19         1.0       3    1  NaN      0      0   7.2250      0           1
# 26         0.0       3    0  NaN      0      0   7.2250      0           1
# 28         1.0       3    1  NaN      0      0   7.8792      0           0
# ...        ...     ...  ...  ...    ...    ...      ...    ...         ...
# 1299       NaN       3    1  NaN      0      0   7.7208      0           0
# 1301       NaN       3    1  NaN      0      0   7.7500      0           0
# 1304       NaN       3    0  NaN      0      0   8.0500      0           0
# 1307       NaN       3    0  NaN      0      0   8.0500      0           0
# 1308       NaN       3    0  NaN      1      1  22.3583      0           1
#
#       Embarked_Q  Embarked_S  Title
# ...

# %%
media_idade_por_titulo['Age'][0]
# Out:
# 32.25215146299484

# %%
index_age_nan = df['Age'][df['Age'].isnull()].index

# %%
index_age_nan
# Out:
# Int64Index([   5,   17,   19,   26,   28,   29,   31,   32,   36,   42,
#             ...
#             1256, 1257, 1271, 1273, 1275, 1299, 1301, 1304, 1307, 1308],
#            dtype='int64', length=263)

# %%
for i in list(index_age_nan):
    df.loc[i,'Age'] = media_idade_por_titulo['Age'][df.loc[i,'Title']]

# %%
df.loc[index_age_nan]
# Out:
#       Survived  Pclass  Sex        Age  SibSp  Parch     Fare  Cabin  \
# 5          0.0       3    0  32.252151      0      0   8.4583      0
# 17         1.0       2    0  32.252151      0      0  13.0000      0
# 19         1.0       3    1  28.569607      0      0   7.2250      0
# 26         0.0       3    0  32.252151      0      0   7.2250      0
# 28         1.0       3    1  28.569607      0      0   7.8792      0
# ...        ...     ...  ...        ...    ...    ...      ...    ...
# 1299       NaN       3    1  28.569607      0      0   7.7208      0
# 1301       NaN       3    1  28.569607      0      0   7.7500      0
# 1304       NaN       3    0  32.252151      0      0   8.0500      0
# 1307       NaN       3    0  32.252151      0      0   8.0500      0
# 1308       NaN       3    0   5.482642      1      1  22.3583      0
#
#       Embarked_C  Embarked_Q  Embarked_S  Title
# 5              0           1           0      0
# ...

# %% [markdown]
# ### FamilySize

# %%
df['FamilySize'] = df['SibSp'] + df['Parch'] + 1

# %%
df.head(3)
# Out:
#    Survived  Pclass  Sex   Age  SibSp  Parch     Fare  Cabin  Embarked_C  \
# 0       0.0       3    0  22.0      1      0   7.2500      0           0
# 1       1.0       1    1  38.0      1      0  71.2833      1           1
# 2       1.0       3    1  26.0      0      0   7.9250      0           0
#
#    Embarked_Q  Embarked_S  Title  FamilySize
# 0           0           1      0           2
# 1           0           0      1           2
# 2           0           1      1           1

# %%
df.drop(['SibSp','Parch'],axis=1,inplace=True)

# %%
df.head(3)
# Out:
#    Survived  Pclass  Sex   Age     Fare  Cabin  Embarked_C  Embarked_Q  \
# 0       0.0       3    0  22.0   7.2500      0           0           0
# 1       1.0       1    1  38.0  71.2833      1           1           0
# 2       1.0       3    1  26.0   7.9250      0           0           0
#
#    Embarked_S  Title  FamilySize
# 0           1      0           2
# 1           0      1           2
# 2           1      1           1

# %% [markdown]
# # 4 - Data Analisis

# %%
df.loc[0:len(df_train)-1].describe()
# Out:
#          Survived      Pclass         Sex         Age        Fare       Cabin  \
# count  891.000000  891.000000  891.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642    0.352413   29.879980   32.204208    0.228956
# std      0.486592    0.836071    0.477990   13.146298   49.693429    0.420397
# min      0.000000    1.000000    0.000000    0.420000    0.000000    0.000000
# 25%      0.000000    2.000000    0.000000   22.000000    7.910400    0.000000
# 50%      0.000000    3.000000    0.000000   30.000000   14.454200    0.000000
# 75%      1.000000    3.000000    1.000000   35.000000   31.000000    0.000000
# max      1.000000    3.000000    1.000000   80.000000  512.329200    1.000000
#
#        Embarked_C  Embarked_Q  Embarked_S       Title  FamilySize
# count  891.000000  891.000000  891.000000  891.000000  891.000000
# mean     0.188552    0.086420    0.725028    0.520763    1.904602
# std      0.391372    0.281141    0.446751    0.712935    1.613459
# ...

# %%
g = sns.heatmap(df.loc[0:len(df_train)-1].corr(),annot=True,fmt=".1f",linewidths=0.2)

# %%
sns.boxplot(x='Age',data=df)

# %%
df.loc[df['Age'] < 1] = 1
sns.boxplot(x='Age',data=df)

# %% [markdown]
# # 5 - Prediction

# %%
train_x = df.iloc[0:len(df_train),1:11]

# %%
train_x
# Out:
#      Pclass  Sex        Age     Fare  Cabin  Embarked_C  Embarked_Q  \
# 0         3    0  22.000000   7.2500      0           0           0
# 1         1    1  38.000000  71.2833      1           1           0
# 2         3    1  26.000000   7.9250      0           0           0
# 3         1    1  35.000000  53.1000      1           0           0
# 4         3    0  35.000000   8.0500      0           0           0
# ..      ...  ...        ...      ...    ...         ...         ...
# 886       2    0  27.000000  13.0000      0           0           0
# 887       1    1  19.000000  30.0000      1           0           0
# 888       3    1  28.569607  23.4500      0           0           0
# 889       1    0  26.000000  30.0000      1           1           0
# 890       3    0  32.000000   7.7500      0           0           1
#
#      Embarked_S  Title  FamilySize
# 0             1      0           2
# 1             0      1           2
# 2             1      1           1
# ...

# %%
train_y = df.loc[0:len(df_train)-1,'Survived']

# %%
train_y
# Out:
# 0      0.0
# 1      1.0
# 2      1.0
# 3      1.0
# 4      0.0
#       ...
# 886    0.0
# 887    1.0
# 888    0.0
# 889    1.0
# 890    0.0
# Name: Survived, Length: 891, dtype: float64

# %% [markdown]
# ### Random Forest Classifier

# %%
rf_clf = RandomForestClassifier(n_estimators=500)

# %%
rf_scores = cross_val_score(rf_clf,train_x,train_y,cv=10)

# %%
'Acuidade = %0.4f (+/- %0.4f)' % (rf_scores.mean(),rf_scores.std() * 2)
# Out:
# 'Acuidade = 0.8148 (+/- 0.0850)'

# %% [markdown]
# ### Ada Boost Classifier

# %%
ad_clf = AdaBoostClassifier(n_estimators=100)

# %%
ad_scores = cross_val_score(ad_clf,train_x,train_y,cv=10)

# %%
'Acuidade = %0.4f (+/- %0.4f)' % (ad_scores.mean(),ad_scores.std() * 2)
# Out:
# 'Acuidade = 0.8160 (+/- 0.0686)'

# %% [markdown]
# ### Multi-layer Perceptron classifier

# %%
mlp_clf = MLPClassifier()

# %%
mlp_scores = cross_val_score(mlp_clf,train_x,train_y,cv=10)

# %%
'Acuidade = %0.4f (+/-) %0.4f'% (mlp_scores.mean(),mlp_scores.std()*2)
# Out:
# 'Acuidade = 0.7756 (+/-) 0.0573'

# %% [markdown]
# ### Data Test Classification

# %%
test_x = df.iloc[len(df_train):,1:11]

# %%
test_x
# Out:
#       Pclass  Sex        Age      Fare  Cabin  Embarked_C  Embarked_Q  \
# 891        3    0  34.500000    7.8292      0           0           1
# 892        3    1  47.000000    7.0000      0           0           0
# 893        2    0  62.000000    9.6875      0           0           1
# 894        3    0  27.000000    8.6625      0           0           0
# 895        3    1  22.000000   12.2875      0           0           0
# ...      ...  ...        ...       ...    ...         ...         ...
# 1304       3    0  32.252151    8.0500      0           0           0
# 1305       1    1  39.000000  108.9000      1           1           0
# 1306       3    0  38.500000    7.2500      0           0           0
# 1307       3    0  32.252151    8.0500      0           0           0
# 1308       3    0   5.482642   22.3583      0           1           0
#
#       Embarked_S  Title  FamilySize
# 891            0      0           1
# 892            1      1           2
# ...

# %%
ad_clf.fit(train_x,train_y)
# Out:
# AdaBoostClassifier(algorithm='SAMME.R', base_estimator=None, learning_rate=1.0,
#                    n_estimators=100, random_state=None)

# %%
test_Y = ad_clf.predict(test_x)

# %%
passenger_id = df_test['PassengerId']

# %%
submission = pd.DataFrame({'PassengerId':passenger_id,'Survived':test_Y.astype(int)})

# %%
submission
# Out:
#      PassengerId  Survived
# 0            892         0
# 1            893         0
# 2            894         0
# 3            895         0
# 4            896         0
# ..           ...       ...
# 413         1305         0
# 414         1306         1
# 415         1307         0
# 416         1308         0
# 417         1309         1
#
# [418 rows x 2 columns]

# %%
submission.to_csv('submission.csv',index=False)
